# %%
import os
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %%
# !pip install langchain-groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
os.environ["GROQ_API_KEY"] = "Your Groq API"

# %%
from langchain_groq import ChatGroq

llamaChatModel = ChatGroq(
    model="llama-3.1-8b-instant"
)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
messages = [
    ("system", "You are an expert historian of Kazi Nazrul Islam. Answer in Bangla."),
    ("human", "Kazi Nazrul Islam er jibon somporke bolo"),
]

# %%
llamaResponse = llamaChatModel.invoke(messages)
print(llamaResponse.content)
# Out:
# Kazi Nazrul Islam (1899-1976) ছিলেন একজন বিশিষ্ট বাঙালি কবি, গীতিকার, গায়ক, সমাজ সংহতকারক, সাংবাদিক এবং সাহিত্যিক। তিনি বাংলা সাহিত্যের অন্যতম স্বনামধন্য কবি হিসেবে পরিচিত।
#
# নাজরুলের জীবন একেক দিনের সাথে সাথে কতটা সমৃদ্ধ হয়ে ওঠে, তা বলাই অসম্ভব। ১৯০৩ সালে তার জন্ম হয় মুর্শিদাবাদ জেলার তরঙ্গপুরে। ছোটবেলা থেকেই তিনি ধর্মীয় সাধনা শুরু করেন এবং ইসলামি সংস্কৃতির সাথে পরিচিত হন। বাল্যকালে তিনি মুহম্মদ মকবুল হিসেবে পরিচিত ছিলেন। বিজ্ঞান ও সাহিত্যে তার সঙ্গতিতে তিনি শিক্ষা গ্রহণ করেন শিক্ষার্থী হিসেবে। নাজরুলকে কবি হিসেবে মূল উদ্ভাবন ঘটানো হয় ১৯২২ সালে প্রবেশিত হওয়া আল হেলাল নামক পত্রিকার কাজে। নাজরুল সময়ের সাথে সাথে সাধারণ মানুষের জীবনের সাথে সংযুক্ত হওয়ায় তিনি বীর বিক্রম রাখাল হিসেবে পরিচিত হয়ে ওঠেন। তিনি শ্রীমতি রতন বেগম মুসলিমা কবের সাথে বিবাহ বন্ধনে আবদ্ধ হন এবং তার সাথে তার দুই সন্তান হাদিস এবং বেদিকা নামের দুই মেয়ে রয়েছে।
#
# ...

# %%
deepChatModel = ChatGroq(
    model="llama-3.1-8b-instant"
)

# %%
deepResponse = deepChatModel.invoke(messages)
print(deepResponse.content)
# Out:
# কাজী নজরুল ইসলাম একজন বিশিষ্ট বাঙালি কবি, সঙ্গীতজ্ঞ, শিল্পী, সমাজকর্মী এবং রাজনৈতিক কর্মী। তিনি ১৯২১ সালে ৩৯ বছর বয়সে প্রথম দেশবন্ধু চিত্তরঞ্জন দাসের পরিকল্পনা অনুযায়ী 'আমরা আর যাপন কবি নই, জীবনের সঙ্গে যাপন' দেশের স্বাধীনতার জন্য লড়াই করে শহীদ হন। এই জন্য তার জন্মদিন ভারত ও বাংলাদেশ সরকার কর্তৃক দেশীয় সঙ্গীত নাগরিক ধন্যবাদজ্ঞাপন দিয়েছে।
#
# কাজী নজরুল ইসলামের জন্ম গোপালনগরের ত্রিশাল ঘাটের কাছে একটি পাটকলে হাজী গুলাম বক্স ও মোমেনা বেগমের ঘরে ১৮৭২ সালের ২৯শে মে হতে পরম্পরায় বহির্ভূত বংশে। স্বাধীনতার প্রথম বিদ্রোহের সময় তার পিতামহ গুলাম রসুল বহুদিনের জন্য কারাবাস করেছিলেন। এই পরিবারের প্রভাবে, কাজী নজরুল ইসলাম কিশোর বয়সেই স্বাধীনতা ও বিপ্লবের প্রতি আকৃষ্ট হয়েওছিলেন। নববিশ্বের ভ্রমন ও শিল্পসম্মেলনে তার প্রভাবিত হয়ে সঙ্গীত ও কবিতা শিল্পের প্রতি তার আগ্রহ বেড়েছিল।
#
# ...
